# %% [markdown]
# 第 0 层（根）：根节点10
#
# 第 1 层：
#
# 10 的左孩子：5
#
# 10 的右孩子：15
#
# 第 2 层：
#
# 5 的左孩子：3
#
# 5 的右孩子：7
#
# 15 的左孩子：None
#
# 15 的右孩子：20
#
#          10
#        /    \
#       5      15
#      /  \      \
#     3    7      20
